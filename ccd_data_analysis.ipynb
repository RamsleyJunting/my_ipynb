# %%
import os
import numpy as np
import cv2
import json
from PIL import Image
import matplotlib.pyplot as plt
import gluoncvth
import torch

root = "/world/data-gpu-112/liliang/ccd"
normal_dir= os.path.join(root, "normal")
abnormal_dir= os.path.join(root, "abnormal")

# for ccd_posi in os.listdir(normal_dir):
#     sub_dir = os.path.join(normal_dir, ccd_posi)
#     for i, normal_img in enumerate(os.listdir(sub_dir)):
#         img = cv2.imread(os.path.join(sub_dir, normal_img))
#         img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#         img = cv2.resize(img, (512,384), interpolation = cv2.INTER_AREA)
#         fig = plt.figure(figsize=(20,10))
#         plt.imshow(img)
#         plt.axis('off')
#         break
#     fig = plt.figure(figsize=(20,10))
#     plt.imshow(img)
#     plt.axis('off')
#     break

img = cv2.imread("/world/data-gpu-112/liliang/ccd/abnormal/Img_12_1_357116.jpg")
img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
img = cv2.resize(img, (512,384), interpolation = cv2.INTER_AREA)
fig = plt.figure(figsize=(20,10))
plt.imshow(img)
plt.axis('off')

fig = plt.figure(figsize=(20,10))
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 511.5, 383.5, -0.5)

# %%
# Get the model
import gluoncv
from gluoncv import model_zoo, data, utils
net = model_zoo.get_model('faster_rcnn_resnet50_v1b_voc', pretrained=True)
im_fname = "/world/data-gpu-112/liliang/ccd/normal/1/Image_5.jpg"
x, orig_img = data.transforms.presets.rcnn.load_test(im_fname)
print(type(x))
print(type(orig_img))

# %%
source_abnormal_dir = os.path.join(root, "source/abnormal")
for abnormal_img in os.listdir(source_abnormal_dir):
    img = cv2.imread(os.path.join(source_abnormal_dir, abnormal_img))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.imwrite(os.path.join(abnormal_dir, abnormal_img).replace("bmp", "jpg"),img)
